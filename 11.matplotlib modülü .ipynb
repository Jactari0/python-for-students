# %% [markdown]
# # matplotlib modülü

# %%
import numpy as np
import pandas as pd

# %%
# import data --dosya aynı klasörde ise 
# farklı klasörde olursa, dosyanın path ini yazmamız gerekir. ;) 

df = pd.read_csv("iris.csv", sep =",")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.columns # features yani öz nitelikler
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.Species
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %% [markdown]
# # .unique()

# %%
df.Species.unique() # kaç farklı tür var ?
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
setosa = df[df.Species == "Iris-setosa"]
setosa
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
versicolor = df[df.Species == "Iris-versicolor"]
versicolor
# Out:
#      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 50   51            7.0           3.2            4.7           1.4
# 51   52            6.4           3.2            4.5           1.5
# 52   53            6.9           3.1            4.9           1.5
# 53   54            5.5           2.3            4.0           1.3
# 54   55            6.5           2.8            4.6           1.5
# 55   56            5.7           2.8            4.5           1.3
# 56   57            6.3           3.3            4.7           1.6
# 57   58            4.9           2.4            3.3           1.0
# 58   59            6.6           2.9            4.6           1.3
# 59   60            5.2           2.7            3.9           1.4
# 60   61            5.0           2.0            3.5           1.0
# 61   62            5.9           3.0            4.2           1.5
# 62   63            6.0           2.2            4.0           1.0
# ...

# %%
virginica = df[df.Species == "Iris-virginica"]
virginica
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 100  101            6.3           3.3            6.0           2.5
# 101  102            5.8           2.7            5.1           1.9
# 102  103            7.1           3.0            5.9           2.1
# 103  104            6.3           2.9            5.6           1.8
# 104  105            6.5           3.0            5.8           2.2
# 105  106            7.6           3.0            6.6           2.1
# 106  107            4.9           2.5            4.5           1.7
# 107  108            7.3           2.9            6.3           1.8
# 108  109            6.7           2.5            5.8           1.8
# 109  110            7.2           3.6            6.1           2.5
# 110  111            6.5           3.2            5.1           2.0
# 111  112            6.4           2.7            5.3           1.9
# 112  113            6.8           3.0            5.5           2.1
# ...

# %%
setosa.describe()
# Out:
#              Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  50.00000       50.00000     50.000000      50.000000      50.00000
# mean   25.50000        5.00600      3.418000       1.464000       0.24400
# std    14.57738        0.35249      0.381024       0.173511       0.10721
# min     1.00000        4.30000      2.300000       1.000000       0.10000
# 25%    13.25000        4.80000      3.125000       1.400000       0.20000
# 50%    25.50000        5.00000      3.400000       1.500000       0.20000
# 75%    37.75000        5.20000      3.675000       1.575000       0.30000
# max    50.00000        5.80000      4.400000       1.900000       0.60000

# %%
versicolor.describe()
# Out:
#               Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count   50.00000      50.000000     50.000000      50.000000     50.000000
# mean    75.50000       5.936000      2.770000       4.260000      1.326000
# std     14.57738       0.516171      0.313798       0.469911      0.197753
# min     51.00000       4.900000      2.000000       3.000000      1.000000
# 25%     63.25000       5.600000      2.525000       4.000000      1.200000
# 50%     75.50000       5.900000      2.800000       4.350000      1.300000
# 75%     87.75000       6.300000      3.000000       4.600000      1.500000
# max    100.00000       7.000000      3.400000       5.100000      1.800000

# %%
virginica.describe()
# Out:
#               Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count   50.00000       50.00000     50.000000      50.000000      50.00000
# mean   125.50000        6.58800      2.974000       5.552000       2.02600
# std     14.57738        0.63588      0.322497       0.551895       0.27465
# min    101.00000        4.90000      2.200000       4.500000       1.40000
# 25%    113.25000        6.22500      2.800000       5.100000       1.80000
# 50%    125.50000        6.50000      3.000000       5.550000       2.00000
# 75%    137.75000        6.90000      3.175000       5.875000       2.30000
# max    150.00000        7.90000      3.800000       6.900000       2.50000

# %%
setosa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             50 non-null     int64
#  1   SepalLengthCm  50 non-null     float64
#  2   SepalWidthCm   50 non-null     float64
#  3   PetalLengthCm  50 non-null     float64
#  4   PetalWidthCm   50 non-null     float64
#  5   Species        50 non-null     object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 2.7+ KB

# %%
versicolor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 50 to 99
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             50 non-null     int64
#  1   SepalLengthCm  50 non-null     float64
#  2   SepalWidthCm   50 non-null     float64
#  3   PetalLengthCm  50 non-null     float64
#  4   PetalWidthCm   50 non-null     float64
#  5   Species        50 non-null     object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 2.7+ KB

# %%
virginica.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 100 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             50 non-null     int64
#  1   SepalLengthCm  50 non-null     float64
#  2   SepalWidthCm   50 non-null     float64
#  3   PetalLengthCm  50 non-null     float64
#  4   PetalWidthCm   50 non-null     float64
#  5   Species        50 non-null     object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 2.7+ KB

# %%
import matplotlib.pyplot as plt

# %%
df1 = df.drop(["Id"], axis = 1)
df1
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
# 4 özelik (sütunlar) ve 3 tane class var, Species içindeki 3 farklı tür.

# %% [markdown]
# # lineplot

# %%
df1.plot(figsize=(8,6))

# dış dosyaya kaydettirmek için
plt.savefig("iris_output.png")
plt.show()

# %%
""" 
Grafiğe göre keskin düşüş ya da yükselişlerin olduğu yerlerde tür (class) 
geçişi olduğu düşünülebilir. Ayrıca her türden de 50'şer  tane olduğunu biliyoruz. 
"""
# Out:
# " \nGrafiğe göre keskin düşüş ya da yükselişlerin olduğu yerlerde tür (class) \ngeçişi olduğu düşünülebilir. Ayrıca her türden de 50'şer  tane olduğunu biliyoruz. \n"

# %%
setosa = df[df.Species == "Iris-setosa"]
versicolor = df[df.Species == "Iris-versicolor"]
virginica = df[df.Species == "Iris-virginica"]

plt.figure(figsize = (8,6))
plt.plot(setosa.Id , setosa.PetalLengthCm, color = "blue", label = "setosa-PetalLengthCm" )
plt.xlabel("Id")
plt.ylabel("PetalLengthCm")
plt.legend()
plt.show()

# %%
plt.figure(figsize = (8,6))
plt.plot(setosa.Id , setosa.PetalLengthCm, color = "blue", label = "setosa-PetalLengthCm" )
plt.plot(versicolor.Id , versicolor.PetalLengthCm, color = "red", label = "versicolor-PetalLengthCm" )
plt.plot(virginica.Id , virginica.PetalLengthCm, color = "green", label = "virginica-PetalLengthCm" )
plt.xlabel("Id")
plt.ylabel("PetalLengthCm")
plt.legend()
plt.show()

# %%
plt.figure(figsize = (14,10))
df1.plot(grid = True, figsize=(8,6))
# Out:
# <AxesSubplot:>

# %%
# plt.figure(figsize = (14,10))
df1.plot(grid = True, linestyle = ":", figsize=(8,6))
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize = (8,6))
plt.plot(setosa.Id , setosa.PetalLengthCm, color = "blue", label = "setosa", )
plt.plot(versicolor.Id , versicolor.PetalLengthCm, color = "red", label = "versicolor" )
plt.plot(virginica.Id , virginica.PetalLengthCm, color = "green", label = "virginica" )
plt.xlabel("Id")
plt.ylabel("PetalLengthCm")
plt.grid(color='g', linestyle='-', linewidth=2)
plt.legend()
plt.show()

# %%
plt.figure(figsize = (8,6))
plt.plot(setosa.Id , setosa.PetalLengthCm, color = "blue", label = "setosa", linestyle = ":")
plt.plot(versicolor.Id , versicolor.PetalLengthCm, color = "red", label = "versicolor", linestyle = ":")
plt.plot(virginica.Id , virginica.PetalLengthCm, color = "green", label = "virginica", linestyle = ":" )
plt.xlabel("Id")
plt.ylabel("PetalLengthCm")
plt.grid(color='grey', linestyle=':', linewidth=2)
plt.legend()
plt.show()

# %%
# alpha parametresi saydamlıkla ilgilidir.

plt.figure(figsize = (8,6))
plt.plot(setosa.Id , setosa.PetalLengthCm, color = "blue", label = "setosa", linestyle = ":", alpha = 0.3)
plt.plot(versicolor.Id , versicolor.PetalLengthCm, color = "red", label = "versicolor", linestyle = ":")
plt.plot(virginica.Id , virginica.PetalLengthCm, color = "green", label = "virginica", linestyle = ":" )
plt.xlabel("Id")
plt.ylabel("PetalLengthCm")
plt.grid(color='grey', linestyle=':', linewidth=2)
plt.legend()
plt.show()

# %% [markdown]
# # scatter plot

# %% [raw]
# Daha çok iki tane feature (özellik - öz niteliğin karşılaştırılması için kullanılır.)

# %%
plt.figure(figsize = (8,6))
plt.scatter(setosa.PetalLengthCm, setosa.PetalWidthCm, color ="red", label ="setosa")
plt.xlabel("PetalLengthCm")
plt.ylabel("PetalWidthCm")
plt.title("scatter plot for setosa")
plt.legend()
plt.show()

# %%
plt.figure(figsize = (8,6))
plt.scatter(setosa.PetalLengthCm, setosa.PetalWidthCm, color ="red", label ="setosa")
plt.scatter(versicolor.PetalLengthCm, versicolor.PetalWidthCm, color ="blue", label ="versicolor")
plt.scatter(virginica.PetalLengthCm, virginica.PetalWidthCm, color ="green", label ="virginica")
plt.xlabel("PetalLengthCm")
plt.ylabel("PetalWidthCm")
plt.title("scatter plot")
plt.legend()
plt.show()

# %% [markdown]
# # histogram plot

# %%
plt.figure(figsize = (8,6))
plt.hist(setosa.PetalLengthCm)
plt.xlabel("PetalLengthCm")
plt.ylabel("Frekansı (Kaç tane var)")
plt.title("histogram")
plt.show()

# %%
# bu data set için histogram pek uygun değil 
# ancak gösterim olarak verilmiştir.

plt.figure(figsize = (8,6))
plt.hist(setosa.PetalLengthCm, bins = 50) # bins bar sayısı anlamındadır. 
plt.xlabel("PetalLengthCm")
plt.ylabel("Frekansı (Kaç tane var)")
plt.title("histogram")
plt.show()

# %%
plt.figure(figsize = (8,6))
plt.hist(setosa.PetalLengthCm, bins = 20, color = "orange")
plt.hist(versicolor.PetalLengthCm, bins = 20, color = "orange")  
plt.hist(setosa.PetalLengthCm, bins = 20, color = "orange")  
plt.xlabel("PetalLengthCm")
plt.ylabel("Frekansı (Kaç tane var)")
plt.title("histogram")
plt.show()

# %%
plt.figure(figsize = (8,6))
plt.hist(setosa.PetalLengthCm, bins = 20, color ="red", label ="setosa")
plt.hist(versicolor.PetalLengthCm, bins = 20, color ="blue", label ="versicolor")
plt.hist(virginica.PetalLengthCm, bins = 20, color ="green", label ="virginica")
plt.xlabel("PetalLengthCm")
plt.ylabel("Frekans")
plt.title("histogram plot")
plt.legend()
plt.show()

# %% [markdown]
# # bar plot

# %%
import numpy as np

# %%
x = np.array([1, 2, 3, 4, 5, 6, 7])
y = x ** 2 + 2 

plt.bar(x, y)
plt.xlabel("x")
plt.ylabel("y")
plt.title("bar plot")
plt.show()

# %%
y
# Out:
# array([ 3,  6, 11, 18, 27, 38, 51], dtype=int32)

# %%
plt.figure(figsize = (6, 4))
x = np.array([1, 2, 3, 4, 5, 6, 7])
a = ["Turkey", "USA", "Germany", "Great Britain", "Spain", "Italy", "France"]
y = x * 2 + 5 

plt.bar(a, y, color="green")
plt.xlabel("x")
plt.ylabel("y")
plt.title("bar plot")
plt.show()

# %% [markdown]
# # subplots

# %%
df.plot(grid = True, subplots = True, figsize=(10,10))
plt.show()

# %%
setosa = df[df.Species == "Iris-setosa"]
versicolor = df[df.Species == "Iris-versicolor"]
virginica = df[df.Species == "Iris-virginica"]

plt.figure(figsize = (12, 6))
plt.subplot(3,1,1) # 3 grafik var, 1. sütunun 1. satırı
plt.plot(setosa.Id, setosa.PetalLengthCm, color = "blue", label = "setosa")
plt.ylabel("setosa-PetalLengthCm")
plt.subplot(3,1,2)  # 3 grafik var, 1. sütunun 2. satırı
plt.plot(versicolor.Id, versicolor.PetalLengthCm, color = "red", label = "versicolor-PetalLengthCm")
plt.ylabel("versicolor")
plt.subplot(3,1,3)
plt.plot(virginica.Id, virginica.PetalLengthCm, color = "green", label = "virginica-PetalLengthCm")
plt.ylabel("virginica")

# dış dosyaya kaydettirmek için
plt.savefig("iris_output_2.jpg")
plt.show()

# %% [markdown]
# # Additional

# %%
# Data for plotting
t = np.arange(0.0, 2.0, 0.01)
s = 1 + np.sin(2 * np.pi * t)

fig, ax = plt.subplots()
ax.plot(t, s)

ax.set(xlabel='time (s)', ylabel='voltage (mV)',
       title='Sinüsel gerilim')
ax.grid()

fig.savefig("1.jpg")
plt.show()

# %%
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)

y1 = np.cos(2 * np.pi * x1) * np.exp(-x1)
y2 = np.cos(2 * np.pi * x2)

fig, (ax1, ax2) = plt.subplots(2, 1)
fig.suptitle('Sönümlü salınım')

ax1.plot(x1, y1, 'o-')
ax1.set_ylabel('Damped oscillation')

ax2.plot(x2, y2, '.-')
ax2.set_xlabel('time (s)')
ax2.set_ylabel('Undamped')

plt.show()

# %%
import matplotlib.pyplot as plt

# Pie chart, where the slices will be ordered and plotted counter-clockwise:
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
sizes = [15, 30, 45, 10]
explode = (0, 0.1, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
r = np.arange(0, 2, 0.01)
theta = 2 * np.pi * r

fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
ax.plot(theta, r)
ax.set_rmax(2)
ax.set_rticks([0.5, 1, 1.5, 2])  # Less radial ticks
ax.set_rlabel_position(-22.5)  # Move radial labels away from plotted line
ax.grid(True)

ax.set_title("Kutupsal koordinatlar", va='bottom')
plt.show()
